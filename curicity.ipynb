# %% [markdown]
# ## LinkedIn Profile Scrapper in Python

# %% [markdown]
# Watch-> LinkedIn Auto Connect Bot with Personalized Messaging: https://www.youtube.com/watch?v=d6EQnjj-Bx0

# %% [markdown]
# Watch Video for this file: https://youtu.be/QVnBCtgS_-U

# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd 
import pickle

# %%
browser = webdriver.Firefox()
browser.get('https://in.linkedin.com/jobs')

# %%
elementID = browser.find_element_by_xpath('//div[2]/section[2]/form/section/input')
elementID.send_keys('data science')
elementID.submit()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(100):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
    df = pd.DataFrame([[], [], []])

# %%
def c_name():
    return soup.find('span', {'class': 'topcard__flavor'}).get_text(strip=True)

# %%
def j_data():
    return soup.find('div', {'class': 'description__text description__text--rich'}).get_text(strip=True)

# %%
def j_name():
    return soup.find('h2', {'class': 'topcard__title'}).get_text(strip=True)

# %%
# !mkdir transcripts
PAUSE_TIME=.5

for i in range(1,200):
    xpath='//li['+str(i)+']/a'
    print(xpath)
    elementID2 = browser.find_element_by_xpath(xpath)
    elementID2.click()
    src = browser.page_source
    soup = BeautifulSoup(src, 'lxml')
    time.sleep(PAUSE_TIME)
    company=c_name()
    job_data=j_data()
    job_name=j_name()
    
    
    
    a_series = pd.Series((c_name(), j_name(),j_data()))
    df = df.append(a_series, ignore_index=True)
# Out:
# mkdir: cannot create directory ‘transcripts’: File exists
# //li[1]/a
# //li[2]/a
# //li[3]/a
# //li[4]/a
# //li[5]/a
# //li[6]/a
# //li[7]/a
# //li[8]/a
# //li[9]/a
# //li[10]/a
# //li[11]/a
# //li[12]/a
# //li[13]/a
# //li[14]/a
# //li[15]/a
# //li[16]/a
# //li[17]/a
# //li[18]/a
# //li[19]/a
# //li[20]/a
# //li[21]/a
# //li[22]/a
# //li[23]/a
# //li[24]/a
# //li[25]/a
# //li[26]/a
# //li[27]/a
# //li[28]/a
# //li[29]/a
# //li[30]/a
# //li[31]/a
# //li[32]/a
# //li[33]/a
# //li[34]/a
# //li[35]/a
# //li[36]/a
# //li[37]/a
# //li[38]/a
# //li[39]/a
# //li[40]/a
# //li[41]/a
# //li[42]/a
# //li[43]/a
# //li[44]/a
# //li[45]/a
# //li[46]/a
# //li[47]/a
# //li[48]/a
# //li[49]/a
# //li[50]/a
# //li[51]/a
# //li[52]/a
# //li[53]/a
# //li[54]/a
# //li[55]/a
# //li[56]/a
# //li[57]/a
# //li[58]/a
# //li[59]/a
# //li[60]/a
# //li[61]/a
# //li[62]/a
# //li[63]/a
# //li[64]/a
# //li[65]/a
# //li[66]/a
# //li[67]/a
# //li[68]/a
# //li[69]/a
# //li[70]/a
# //li[71]/a
# //li[72]/a
# //li[73]/a
# ...

# %%
df
# Out:
#                                0  \
# 0                           5i5j
# 1    Leonia Holistic Destination
# 2                     Convosight
# 3     Katam Technology Solutions
# 4                        Vidooly
# ..                           ...
# 139                      Genpact
# 140                     MERCADOS
# 141                 Mindsnetwork
# 142                      Genpact
# 143             Schoolybooks.com
#
#                                                      1  \
# 0    Data Scientist (1-3 yrs) Bangalore/Delhi NCR (...
# 1    Baby Destination - Senior Data Research Analys...
# 2    Convosight - Senior Data Scientist - Machine L...
# 3    Big Data/Senior Developer - Hadoop/Spark/Desig...
# 4    Vidooly - Big Data Developer - AWS/Redshift/Ha...
# ..                                                 ...
# 139          Business Analyst - Data Science-HEA002764
# 140  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# 141  Data Scientist - Algorithm & Machine Learning ...
# ...

# %%
df.dropna()
# Out:
#                                0  \
# 0                           5i5j
# 1    Leonia Holistic Destination
# 2                     Convosight
# 3     Katam Technology Solutions
# 4                        Vidooly
# ..                           ...
# 139                      Genpact
# 140                     MERCADOS
# 141                 Mindsnetwork
# 142                      Genpact
# 143             Schoolybooks.com
#
#                                                      1  \
# 0    Data Scientist (1-3 yrs) Bangalore/Delhi NCR (...
# 1    Baby Destination - Senior Data Research Analys...
# 2    Convosight - Senior Data Scientist - Machine L...
# 3    Big Data/Senior Developer - Hadoop/Spark/Desig...
# 4    Vidooly - Big Data Developer - AWS/Redshift/Ha...
# ..                                                 ...
# 139          Business Analyst - Data Science-HEA002764
# 140  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# 141  Data Scientist - Algorithm & Machine Learning ...
# ...

# %%
df
# Out:
#                                0  \
# 0                           5i5j
# 1    Leonia Holistic Destination
# 2                     Convosight
# 3     Katam Technology Solutions
# 4                        Vidooly
# ..                           ...
# 139                      Genpact
# 140                     MERCADOS
# 141                 Mindsnetwork
# 142                      Genpact
# 143             Schoolybooks.com
#
#                                                      1  \
# 0    Data Scientist (1-3 yrs) Bangalore/Delhi NCR (...
# 1    Baby Destination - Senior Data Research Analys...
# 2    Convosight - Senior Data Scientist - Machine L...
# 3    Big Data/Senior Developer - Hadoop/Spark/Desig...
# 4    Vidooly - Big Data Developer - AWS/Redshift/Ha...
# ..                                                 ...
# 139          Business Analyst - Data Science-HEA002764
# 140  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# 141  Data Scientist - Algorithm & Machine Learning ...
# ...

# %%
df.drop_duplicates(keep = False, inplace = True)

# %%
df
# Out:
#                                 0  \
# 2                      Convosight
# 4                         Vidooly
# 5    Spinnaker Corporate Advisors
# 6                  Alb Associates
# 7                       Talent1st
# ..                            ...
# 135             Snaphunt Pte. Ltd
# 137                   Eagles Hunt
# 140                      MERCADOS
# 141                  Mindsnetwork
# 143              Schoolybooks.com
#
#                                                      1  \
# 2    Convosight - Senior Data Scientist - Machine L...
# 4    Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 5    Data Science Instructor - Python/Machine Learn...
# 6                                 Manager Data Science
# 7    Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                 ...
# 135  Artificial Intelligence Engineer - Data Modeli...
# 137  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# ...

# %%
df.to_csv('clean3_data.csv')
