# %%
import pandas as pd

# %%
data=pd.read_csv('/home/siddharth/scraping/LinkedIn-Profile-Scrapper-in-Python/transcripts/withstopwords_data.csv')

# %%
data
# Out:
#     Unnamed: 0                       company  \
# 0            0                    Convosight
# 1            1                       Vidooly
# 2            2  Spinnaker Corporate Advisors
# 3            3                Alb Associates
# 4            4                     Talent1st
# ..         ...                           ...
# 75          75             Snaphunt Pte. Ltd
# 76          76                   Eagles Hunt
# 77          77                      MERCADOS
# 78          78                  Mindsnetwork
# 79          79              Schoolybooks.com
#
#                                                 tital  \
# 0   Convosight - Senior Data Scientist - Machine L...
# 1   Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 2   Data Science Instructor - Python/Machine Learn...
# 3                                Manager Data Science
# 4   Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                ...
# 75  Artificial Intelligence Engineer - Data Modeli...
# 76  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# 77  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# 78  Data Scientist - Algorithm & Machine Learning ...
# 79  Senior Analytics Manager - Predictive & Statis...
#
#                                           description  \
# 0   Convosight is the world's first global data an...
# 1   Job DescriptionLooking for the big data engine...
# 2   ResponsibilitiesCurrently we are looking for a...
# 3   Good exposure as Data scienitstWorking on R, P...
# 4   Role & ResponsibilitiesModelling and Statistic...
# ..                                                ...
# 75  About The OfferDevelop and implement AI projec...
# 76  Job Description-Prior experience of high-level...
# 77  Job title : Data AnalystReports to: L1: Manage...
# 78  About The WorkJob Description :You will be bui...
# 79  Job DescriptionRole :Senior Manager AnalyticsR...
#
#                                            without_sw
# 0   ['Convosight', 'world', "'s", 'first', 'global...
# 1   ['Job', 'DescriptionLooking', 'big', 'data', '...
# 2   ['ResponsibilitiesCurrently', 'looking', 'part...
# 3   ['Good', 'exposure', 'Data', 'scienitstWorking...
# 4   ['Role', '&', 'ResponsibilitiesModelling', 'St...
# ..                                                ...
# 75  ['About', 'The', 'OfferDevelop', 'implement', ...
# 76  ['Job', 'Description-Prior', 'experience', 'hi...
# 77  ['Job', 'title', ':', 'Data', 'AnalystReports'...
# 78  ['About', 'The', 'WorkJob', 'Description', ':'...
# 79  ['Job', 'DescriptionRole', ':', 'Senior', 'Man...
#
# [80 rows x 5 columns]

# %%
data.insert(5, "clean_round_1","")

# %%
import re
import string

def clean_text_round1(text):
    #print (text)
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
   # print(text)
    text = re.sub('\[.*?\]', '', text)
   # print(text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
   # print(text)
    text = re.sub('\w*\d\w*', '', text)
    print(text)
    return text

# %%
data
# Out:
#     Unnamed: 0                       company  \
# 0            0                    Convosight
# 1            1                       Vidooly
# 2            2  Spinnaker Corporate Advisors
# 3            3                Alb Associates
# 4            4                     Talent1st
# ..         ...                           ...
# 75          75             Snaphunt Pte. Ltd
# 76          76                   Eagles Hunt
# 77          77                      MERCADOS
# 78          78                  Mindsnetwork
# 79          79              Schoolybooks.com
#
#                                                 tital  \
# 0   Convosight - Senior Data Scientist - Machine L...
# 1   Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 2   Data Science Instructor - Python/Machine Learn...
# 3                                Manager Data Science
# 4   Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                ...
# 75  Artificial Intelligence Engineer - Data Modeli...
# 76  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# 77  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# 78  Data Scientist - Algorithm & Machine Learning ...
# 79  Senior Analytics Manager - Predictive & Statis...
#
#                                           description  \
# 0   Convosight is the world's first global data an...
# 1   Job DescriptionLooking for the big data engine...
# 2   ResponsibilitiesCurrently we are looking for a...
# 3   Good exposure as Data scienitstWorking on R, P...
# 4   Role & ResponsibilitiesModelling and Statistic...
# ..                                                ...
# 75  About The OfferDevelop and implement AI projec...
# 76  Job Description-Prior experience of high-level...
# 77  Job title : Data AnalystReports to: L1: Manage...
# 78  About The WorkJob Description :You will be bui...
# 79  Job DescriptionRole :Senior Manager AnalyticsR...
#
#                                            without_sw clean_round_1
# 0   ['Convosight', 'world', "'s", 'first', 'global...
# 1   ['Job', 'DescriptionLooking', 'big', 'data', '...
# 2   ['ResponsibilitiesCurrently', 'looking', 'part...
# 3   ['Good', 'exposure', 'Data', 'scienitstWorking...
# 4   ['Role', '&', 'ResponsibilitiesModelling', 'St...
# ..                                                ...           ...
# 75  ['About', 'The', 'OfferDevelop', 'implement', ...
# 76  ['Job', 'Description-Prior', 'experience', 'hi...
# 77  ['Job', 'title', ':', 'Data', 'AnalystReports'...
# 78  ['About', 'The', 'WorkJob', 'Description', ':'...
# 79  ['Job', 'DescriptionRole', ':', 'Senior', 'Man...
#
# [80 rows x 6 columns]

# %%
#for i in range(0,80):
data.clean_round_1[0]=clean_text_round1(data.without_sw[0])
# Out:
# /home/siddharth/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data
# Out:
#     Unnamed: 0                       company  \
# 0            0                    Convosight
# 1            1                       Vidooly
# 2            2  Spinnaker Corporate Advisors
# 3            3                Alb Associates
# 4            4                     Talent1st
# ..         ...                           ...
# 75          75             Snaphunt Pte. Ltd
# 76          76                   Eagles Hunt
# 77          77                      MERCADOS
# 78          78                  Mindsnetwork
# 79          79              Schoolybooks.com
#
#                                                 tital  \
# 0   Convosight - Senior Data Scientist - Machine L...
# 1   Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 2   Data Science Instructor - Python/Machine Learn...
# 3                                Manager Data Science
# 4   Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                ...
# 75  Artificial Intelligence Engineer - Data Modeli...
# 76  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# 77  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# 78  Data Scientist - Algorithm & Machine Learning ...
# 79  Senior Analytics Manager - Predictive & Statis...
#
#                                           description  \
# 0   Convosight is the world's first global data an...
# 1   Job DescriptionLooking for the big data engine...
# 2   ResponsibilitiesCurrently we are looking for a...
# 3   Good exposure as Data scienitstWorking on R, P...
# 4   Role & ResponsibilitiesModelling and Statistic...
# ..                                                ...
# 75  About The OfferDevelop and implement AI projec...
# 76  Job Description-Prior experience of high-level...
# 77  Job title : Data AnalystReports to: L1: Manage...
# 78  About The WorkJob Description :You will be bui...
# 79  Job DescriptionRole :Senior Manager AnalyticsR...
#
#                                            without_sw clean_round_1
# 0   ['Convosight', 'world', "'s", 'first', 'global...
# 1   ['Job', 'DescriptionLooking', 'big', 'data', '...
# 2   ['ResponsibilitiesCurrently', 'looking', 'part...
# 3   ['Good', 'exposure', 'Data', 'scienitstWorking...
# 4   ['Role', '&', 'ResponsibilitiesModelling', 'St...
# ..                                                ...           ...
# 75  ['About', 'The', 'OfferDevelop', 'implement', ...
# 76  ['Job', 'Description-Prior', 'experience', 'hi...
# 77  ['Job', 'title', ':', 'Data', 'AnalystReports'...
# 78  ['About', 'The', 'WorkJob', 'Description', ':'...
# 79  ['Job', 'DescriptionRole', ':', 'Senior', 'Man...
#
# [80 rows x 6 columns]
