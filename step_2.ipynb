# %%
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import nltk
print (nltk.download('stopwords'))
# Out:
# True
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/siddharth/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data1=pd.read_csv("/home/siddharth/scraping/LinkedIn-Profile-Scrapper-in-Python/transcripts/final_clean_data.csv")

# %%
data1
# Out:
#                          company  \
# 0                     Convosight
# 1                        Vidooly
# 2   Spinnaker Corporate Advisors
# 3                 Alb Associates
# 4                      Talent1st
# ..                           ...
# 75             Snaphunt Pte. Ltd
# 76                   Eagles Hunt
# 77                      MERCADOS
# 78                  Mindsnetwork
# 79              Schoolybooks.com
#
#                                                 tital  \
# 0   Convosight - Senior Data Scientist - Machine L...
# 1   Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 2   Data Science Instructor - Python/Machine Learn...
# 3                                Manager Data Science
# 4   Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                ...
# 75  Artificial Intelligence Engineer - Data Modeli...
# 76  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# 77  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# ...

# %%
data1.insert(3, "without_sw", "")

# %%
data1
# Out:
#                          company  \
# 0                     Convosight
# 1                        Vidooly
# 2   Spinnaker Corporate Advisors
# 3                 Alb Associates
# 4                      Talent1st
# ..                           ...
# 75             Snaphunt Pte. Ltd
# 76                   Eagles Hunt
# 77                      MERCADOS
# 78                  Mindsnetwork
# 79              Schoolybooks.com
#
#                                                 tital  \
# 0   Convosight - Senior Data Scientist - Machine L...
# 1   Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 2   Data Science Instructor - Python/Machine Learn...
# 3                                Manager Data Science
# 4   Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                ...
# 75  Artificial Intelligence Engineer - Data Modeli...
# 76  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# 77  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
df = pd.DataFrame()
df.insert(0, "without_sw", "") 
for i in range(0,80):
    text = data1.description[i]
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    data1.without_sw[i]=tokens_without_sw

# %%
data1
# Out:
#                          company  \
# 0                     Convosight
# 1                        Vidooly
# 2   Spinnaker Corporate Advisors
# 3                 Alb Associates
# 4                      Talent1st
# ..                           ...
# 75             Snaphunt Pte. Ltd
# 76                   Eagles Hunt
# 77                      MERCADOS
# 78                  Mindsnetwork
# 79              Schoolybooks.com
#
#                                                 tital  \
# 0   Convosight - Senior Data Scientist - Machine L...
# 1   Vidooly - Big Data Developer - AWS/Redshift/Ha...
# 2   Data Science Instructor - Python/Machine Learn...
# 3                                Manager Data Science
# 4   Data Scientist - Data Mining & Modeling - R/Py...
# ..                                                ...
# 75  Artificial Intelligence Engineer - Data Modeli...
# 76  Tech Lead/Architect - Java/Python/NLP (5-10 yr...
# 77  Mercados - Data Analyst - Python/R (2-3 yrs) D...
# ...

# %%
data1.without_sw[0]
# Out:
# ['Convosight',
#  'world',
#  "'s",
#  'first',
#  'global',
#  'data',
#  'analytics',
#  'SaaS',
#  'platform',
#  'community',
#  'admins',
#  '.',
#  'We',
#  'disrupting',
#  'way',
#  'communities',
#  'managed',
#  ',',
#  'moderated',
#  'grown',
#  'using',
#  'power',
#  'data',
#  'analytics',
#  'machine',
#  'learning',
#  '.',
#  'Convosight',
#  'funded',
#  'startup',
#  'engineering',
#  'offices',
#  'Delhi',
#  'Hyderabad.Website',
#  ':',
#  'www.convosight.comLocation',
#  ':',
#  'DelhiJob',
#  'description',
#  'Senior',
#  'Data',
#  'Scientist',
#  ':',
#  'To',
#  'lead',
#  'spearhead',
#  'efforts',
#  'using',
#  'textual',
#  'analysis',
#  'via',
#  'Machine',
#  'learning',
#  'develop',
#  'solutions',
#  'complex',
#  'business',
#  'problems',
#  ',',
#  'looking',
#  'Sr.',
#  'Data',
#  'Scientist',
#  'lead',
#  'Data',
#  'Science',
#  'Business',
#  'Intelligence',
#  '&',
#  'Reporting',
#  'Team.ResponsibilitiesCollaborate',
# ...

# %%
data1.to_csv('withstopwords_data.csv')
